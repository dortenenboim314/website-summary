# %%
import pandas as pd

# %%
train = pd.read_csv('train_val.csv')

# %%
train.head()
# Out:
#                                             markdown language  type  \
# 0  ![](/static/images/icons/wikipedia.png)\n![Wik...  english  wiki
# 1  ![](https://en.wikipedia.org/static/images/don...  english  wiki
# 2  ![](/static/images/icons/wikipedia.png)\n![Wik...  english  wiki
# 3  ![](https://en.wikipedia.org/static/images/don...   german  wiki
# 4  ![](/static/images/icons/wikipedia.png)\n![ويك...   arabic  wiki
#
#       source         domain                title  word_count  content_length  \
# 0  wikipedia  wikipedia.org     Renewable_energy       16319          173030
# 1  wikipedia  wikipedia.org  Inorganic_chemistry        2735           26061
# 2  wikipedia  wikipedia.org    Augmented_reality       11293          100434
# 3  wikipedia  wikipedia.org                  Sun          64            1105
# 4  wikipedia  wikipedia.org        Nuclear_power        6437          100283
#
#              category  split
# 0  energy_environment  train
# 1   physics_chemistry  train
# ...

# %%
evalaution = pd.read_csv('evaluation.csv')

# %%
evalaution.head()
# Out:
#                                             markdown language  type  \
# 0  Published Time: 2025-05-28T10:52:38Z\n\nCzech ...  english  news
# 1  # Scientists find strongest evidence yet of li...  english  news
# 2  Published Time: 2025-06-04T16:05:11.539Z\n\nIs...  english  news
# 3  # World-first blood cancer therapy to be given...  english  news
# 4  # Breakthrough cancer drug doubles survival in...  english  news
#
#        source           domain  \
# 0  evaluation       apnews.com
# 1  evaluation  www.reuters.com
# 2  evaluation      www.cnn.com
# 3  evaluation      www.bbc.com
# 4  evaluation      www.bbc.com
#
#                                                title  word_count  \
# 0  Czech Republic blames China for cyberattack | ...       12335
# 1  Scientists find strongest evidence yet of life...         488
# 2  Getting to the moon in months, weeks or days -...        3373
# 3  Cancer: World-first 'Trojan horse' therapy to ...        1236
# ...
