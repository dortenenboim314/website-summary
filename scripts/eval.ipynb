# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
from IPython.display import display
import evaluate

# %%
df = pd.read_csv("../dataset/results.csv")
df.columns
# Out:
# Index(['url', 'raw_markdown', 'language', 'domain', 'source', 'length',
#        'word_count', 'cleaned_markdown', 'summary_gt', 'summary_gt_extractive',
#        'summary_random', 'summary_lsa', 'summary_text_rank',
#        'summary_spacy_textrank', 'summary_sentence_transformer_mpnet',
#        'summary_sentence_transformer_distiluse', 'summary_claude_haiku_3_5',
#        'summary_claude_sonnet_4', 'summary_random_latency',
#        'summary_lsa_latency', 'summary_text_rank_latency',
#        'summary_spacy_textrank_latency',
#        'summary_sentence_transformer_mpnet_latency',
#        'summary_sentence_transformer_distiluse_latency',
#        'summary_claude_haiku_3_5_latency', 'summary_claude_sonnet_4_latency'],
#       dtype='object')

# %%
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

# %%
# 3. Preprocessing function
def preprocess(text: str) -> str:
    return " ".join(text.lower().split())

# %%
# Cell 3: Compute per-output metrics
summarizers = ['random', 'lsa', 'text_rank', 'spacy_textrank', "sentence_transformer_mpnet", 
               "sentence_transformer_distiluse", "claude_haiku_3_5", "claude_sonnet_4"]


records = []

for name in summarizers:
    print(f"Processing summarizer: {name}")
    pred_col = f"summary_{name}"
    
    # gt_col = "summary_gt"
    gt_col = "summary_gt_extractive"
    
    # Drop NaNs for evaluation
    eval_df = df.dropna(subset=[pred_col, gt_col])
    refs  = eval_df[gt_col].map(preprocess).tolist()
    preds = eval_df[pred_col].map(preprocess).tolist()
    
    # Compute BERTScore once per summarizer
    bert_scores = bertscore.compute(
        predictions=preds,
        references=refs,
        model_type="xlm-roberta-base",
        idf=False,
        batch_size=16,
    )
    
    # Now record metrics for each example
    for i, idx in enumerate(eval_df.index):
        # ROUGE on the single example
        rouge_score = rouge.compute(
            predictions=[preds[i]],
            references=[refs[i]],
            use_stemmer=True
        )
        
        records.append({
            "url":             df.loc[idx, "url"],
            "language":        df.loc[idx, "language"],
            "gt":              df.loc[idx, gt_col],
            "summary_pred":    df.loc[idx, pred_col],
            "length":          df.loc[idx, "length"],
            "summarizer":      name,
            "rouge1":          rouge_score["rouge1"],
            "rouge2":          rouge_score["rouge2"],
            "rougeL":          rouge_score["rougeL"],
            "rougeLsum":       rouge_score["rougeLsum"],
            "bert_precision":  bert_scores["precision"][i],
            "bert_recall":     bert_scores["recall"][i],
            "bert_f1":         bert_scores["f1"][i],
        })
# Out:
# Processing summarizer: random
# Processing summarizer: lsa
# Processing summarizer: text_rank
# Processing summarizer: spacy_textrank
# Processing summarizer: sentence_transformer_mpnet
# Processing summarizer: sentence_transformer_distiluse
# Processing summarizer: claude_haiku_3_5
# Processing summarizer: claude_sonnet_4

# %%
# Build the per-example metrics DataFrame
long_df = pd.DataFrame.from_records(records)

# %%
# Cell 4: Save and display
long_df.to_csv("../dataset/metrics_by_example.csv", index=False)
display("Per-example evaluation metrics", long_df)
print("✅ Saved per-example metrics to '../dataset/metrics_by_example.csv'")
# Out:
# 'Per-example evaluation metrics'
#                                                     url language  \
# 0     https://simple.wikipedia.org/wiki/Space_explor...  english
# 1      https://en.wikipedia.org/wiki/Portal:Mathematics  english
# 2             https://simple.wikipedia.org/wiki/History  english
# 3     https://en.wikipedia.org/wiki/Outline_of_machi...  english
# 4     https://en.wikipedia.org/wiki/Category:Astroph...  english
# ...                                                 ...      ...
# 1564   https://www.bbc.com/arabic/tv-and-radio-67957982   arabic
# 1565   https://www.bbc.com/arabic/articles/cj3rnmlkp5no   arabic
# 1566           https://www.aljazeera.com/climate-crisis   arabic
# 1567   https://www.bbc.com/arabic/articles/c0rgn20w5z2o   arabic
# 1568   https://www.bbc.com/arabic/articles/c24pmrg927yo   arabic
#
#                                                      gt  \
# 0     Space exploration is a term which describes se...
# 1     Mathematics is the study of representing and r...
# 2     History is the study of past events. A person ...
# 3     The following outline is provided as an overvi...
# 4     Astrophysics is the branch of astronomy that d...
# ...                                                 ...
# 1564  تربط منظمة الصحة العالمية الأخطاء الطبية الأكث...
# 1565  وتُعدّ أمراض القلب والأوعية الدموية السبب الأو...
# 1566  Six dead, thousands displaced as floods hit so...
# 1567  ينذر التغير المناخي بتداعيات قد تغيّر شكل كوكب...
# 1568  يرى برنامج الأمم المتحدة للبيئة (اليونيب) أن ت...
#
#                                            summary_pred  length  \
# 0     There are many reasons for space exploration.\...    3603
# 1     Portal topics - (Random portal) Mathematics is...   71678
# 2     History is the study of past events.\nA person...    3659
# 3     [3] These algorithms operate by building a mod...  176774
# 4     Astrophysics is the branch of astronomy that d...    2469
# ...                                                 ...     ...
# 1564  تربط منظمة الصحة العالمية الأخطاء الطبية الأكث...    2458
# 1565  وتُعدّ أمراض القلب والأوعية الدموية السبب الأو...   12087
# 1566  'Exceptionally large floods' swept through Gui...    1319
# 1567  ينذر التغير المناخي بتداعيات قد تغيّر شكل كوكب...   11747
# 1568  أعداد ضحاياه تتجاوز أربعة ملايين نسمة في كل عا...   10940
#
#            summarizer    rouge1    rouge2    rougeL  rougeLsum  \
# 0              random  0.261905  0.024390  0.119048   0.119048
# 1              random  0.422360  0.238994  0.322981   0.322981
# 2              random  0.452381  0.268293  0.404762   0.404762
# 3              random  0.341880  0.034783  0.153846   0.153846
# 4              random  0.938547  0.937853  0.938547   0.938547
# ...               ...       ...       ...       ...        ...
# 1564  claude_sonnet_4  0.000000  0.000000  0.000000   0.000000
# 1565  claude_sonnet_4  0.500000  0.000000  0.500000   0.500000
# 1566  claude_sonnet_4  0.865672  0.861538  0.865672   0.865672
# 1567  claude_sonnet_4  0.000000  0.000000  0.000000   0.000000
# 1568  claude_sonnet_4  0.000000  0.000000  0.000000   0.000000
#
#       bert_precision  bert_recall   bert_f1
# 0           0.863439     0.857694  0.860557
# 1           0.875098     0.875510  0.875304
# 2           0.871200     0.938371  0.903539
# 3           0.834351     0.861427  0.847673
# 4           0.981122     0.998952  0.989957
# ...              ...          ...       ...
# 1564        0.966060     0.846090  0.902103
# 1565        0.969366     0.851170  0.906431
# 1566        0.976410     0.945058  0.960478
# 1567        0.983837     0.870040  0.923446
# 1568        0.845233     0.807423  0.825895
#
# [1569 rows x 13 columns]
# ✅ Saved per-example metrics to '../dataset/metrics_by_example.csv'

# %%
# Define which metric columns to average
long_copy = long_df.copy()

# drop arabic and chinese
# long_copy = long_copy[~long_copy["language"].isin(["ar", "zh"])]

metrics = [
    "rouge1", "rouge2", "rougeL", "rougeLsum",
    "bert_precision", "bert_recall", "bert_f1"
]

# 1) Average result per summarizer
avg_by_summarizer = (
    long_copy
    .groupby("summarizer")[metrics]
    .mean()
    .reset_index()
)

# 2) Average result per summarizer per language
avg_by_summarizer_lang = (
    long_copy
    .groupby(["summarizer", "language"])[metrics]
    .mean()
    .sort_values(by=["language"])
    .reset_index()
)

# (Optional) Display or save
print("=== Avg per summarizer ===")
display(avg_by_summarizer.sort_values(by="rougeLsum", ascending=False))

print("\n=== Avg per summarizer per language ===")
display(avg_by_summarizer_lang)
# Out:
# === Avg per summarizer ===
#                        summarizer    rouge1    rouge2    rougeL  rougeLsum  \
# 1                 claude_sonnet_4  0.576508  0.512536  0.551489   0.551489
# 0                claude_haiku_3_5  0.503792  0.420164  0.468924   0.468924
# 5      sentence_transformer_mpnet  0.423480  0.324303  0.383698   0.383698
# 4  sentence_transformer_distiluse  0.422092  0.317798  0.379869   0.379869
# 6                  spacy_textrank  0.375064  0.255934  0.297274   0.297274
# 2                             lsa  0.355671  0.226742  0.291590   0.291590
# 7                       text_rank  0.328629  0.212571  0.273800   0.273800
# 3                          random  0.278959  0.147063  0.221238   0.221238
#
#    bert_precision  bert_recall   bert_f1
# 1        0.940695     0.911053  0.925308
# 0        0.926781     0.902579  0.914246
# 5        0.881709     0.899450  0.889948
# 4        0.877966     0.899668  0.888166
# 6        0.865142     0.884220  0.874209
# 2        0.857639     0.886578  0.871518
# 7        0.847339     0.884469  0.865080
# 3        0.856994     0.864125  0.860211
# === Avg per summarizer per language ===
#                         summarizer language    rouge1    rouge2    rougeL  \
# 0                 claude_haiku_3_5   arabic  0.417349  0.285136  0.416288
# 1   sentence_transformer_distiluse   arabic  0.359172  0.154500  0.352418
# 2                              lsa   arabic  0.220744  0.080777  0.202210
# 3                        text_rank   arabic  0.217467  0.086294  0.197122
# 4                  claude_sonnet_4   arabic  0.309403  0.223218  0.309403
# 5       sentence_transformer_mpnet   arabic  0.308136  0.188822  0.307181
# 6                   spacy_textrank   arabic  0.426925  0.210570  0.423967
# 7                           random   arabic  0.247815  0.100393  0.235130
# 8                  claude_sonnet_4  chinese  0.271154  0.202733  0.271154
# 9       sentence_transformer_mpnet  chinese  0.209314  0.117125  0.200264
# 10                       text_rank  chinese  0.165059  0.066667  0.156401
# 11                  spacy_textrank  chinese  0.168037  0.107645  0.157048
# 12                             lsa  chinese  0.182059  0.109524  0.174122
# 13  sentence_transformer_distiluse  chinese  0.186264  0.109929  0.182601
# 14                claude_haiku_3_5  chinese  0.079762  0.015083  0.077564
# 15                          random  chinese  0.099395  0.047619  0.099395
# 16  sentence_transformer_distiluse  english  0.490605  0.388190  0.439069
# 17                  spacy_textrank  english  0.444683  0.313920  0.341587
# 18      sentence_transformer_mpnet  english  0.519789  0.422359  0.474120
# 19                          random  english  0.301661  0.149798  0.226434
# 20                claude_haiku_3_5  english  0.653772  0.576020  0.612026
# 21                             lsa  english  0.434426  0.295208  0.355931
# 22                       text_rank  english  0.415055  0.289055  0.346447
# 23                 claude_sonnet_4  english  0.731001  0.679077  0.702936
# 24                  spacy_textrank   french  0.365207  0.226744  0.262901
# 25                claude_haiku_3_5   french  0.483770  0.394417  0.438228
# 26      sentence_transformer_mpnet   french  0.385156  0.222999  0.295356
# 27                       text_rank   french  0.262685  0.151409  0.200067
# 28                 claude_sonnet_4   french  0.559837  0.504756  0.536423
# 29  sentence_transformer_distiluse   french  0.417628  0.275040  0.335995
# 30                             lsa   french  0.337976  0.185151  0.253467
# 31                          random   french  0.328701  0.196294  0.261011
# 32                 claude_sonnet_4   german  0.509239  0.452043  0.479188
# 33                             lsa   german  0.319537  0.211025  0.267010
# 34                       text_rank   german  0.307097  0.205723  0.257404
# 35      sentence_transformer_mpnet   german  0.440839  0.357019  0.407422
# 36                claude_haiku_3_5   german  0.452358  0.391099  0.428946
# 37                          random   german  0.264262  0.156666  0.219421
# 38  sentence_transformer_distiluse   german  0.466755  0.391017  0.434795
# 39                  spacy_textrank   german  0.377140  0.290950  0.293414
# 40                  spacy_textrank  spanish  0.333191  0.224751  0.257674
# 41                          random  spanish  0.332843  0.192112  0.262735
# 42  sentence_transformer_distiluse  spanish  0.421091  0.329921  0.372086
# 43                             lsa  spanish  0.342811  0.207473  0.265144
# 44                 claude_sonnet_4  spanish  0.565112  0.470087  0.520121
# 45                claude_haiku_3_5  spanish  0.519074  0.409785  0.459501
# 46      sentence_transformer_mpnet  spanish  0.386217  0.307810  0.343796
# 47                       text_rank  spanish  0.292848  0.185870  0.231857
#
#     rougeLsum  bert_precision  bert_recall   bert_f1
# 0    0.416288        0.956136     0.891755  0.922375
# 1    0.352418        0.900554     0.926784  0.913017
# 2    0.202210        0.850056     0.869241  0.859017
# 3    0.197122        0.847097     0.882530  0.863873
# 4    0.309403        0.939056     0.875484  0.905526
# 5    0.307181        0.903485     0.926702  0.914523
# 6    0.423967        0.914309     0.918727  0.916239
# 7    0.235130        0.876768     0.851894  0.863857
# 8    0.271154        0.914290     0.871221  0.891857
# 9    0.200264        0.866315     0.880316  0.872864
# 10   0.156401        0.851089     0.883354  0.866825
# 11   0.157048        0.838255     0.865655  0.851517
# 12   0.174122        0.852180     0.883592  0.867376
# 13   0.182601        0.870607     0.888607  0.879231
# 14   0.077564        0.911823     0.879238  0.894945
# 15   0.099395        0.866570     0.875693  0.870769
# 16   0.439069        0.881302     0.900582  0.890309
# 17   0.341587        0.873355     0.888182  0.880350
# 18   0.474120        0.891640     0.905603  0.898083
# 19   0.226434        0.855448     0.858478  0.856759
# 20   0.612026        0.935433     0.926071  0.930537
# 21   0.355931        0.864690     0.894297  0.878904
# 22   0.346447        0.856878     0.889197  0.872256
# 23   0.702936        0.956027     0.940731  0.948078
# 24   0.262901        0.856340     0.870379  0.862929
# 25   0.438228        0.917685     0.883371  0.899983
# 26   0.295356        0.866973     0.861217  0.863927
# 27   0.200067        0.813658     0.864148  0.837875
# 28   0.536423        0.940138     0.901262  0.920043
# 29   0.335995        0.867877     0.868211  0.867906
# 30   0.253467        0.855352     0.868556  0.861686
# 31   0.261011        0.863669     0.860746  0.861950
# 32   0.479188        0.925186     0.886433  0.905192
# 33   0.267010        0.847790     0.876834  0.861847
# 34   0.257404        0.842345     0.870798  0.856044
# 35   0.407422        0.887130     0.885819  0.886159
# 36   0.428946        0.911025     0.877441  0.893762
# 37   0.219421        0.847512     0.856083  0.851506
# 38   0.434795        0.887787     0.891692  0.889412
# 39   0.293414        0.866493     0.874007  0.870102
# 40   0.257674        0.847582     0.889241  0.867420
# 41   0.262735        0.849976     0.885266  0.866834
# 42   0.372086        0.863442     0.918150  0.889341
# 43   0.265144        0.853061     0.891076  0.871165
# 44   0.520121        0.931818     0.898763  0.914830
# 45   0.459501        0.919132     0.889194  0.903796
# 46   0.343796        0.861358     0.917686  0.887958
# 47   0.231857        0.839993     0.893903  0.865658

# %%
# for each summarizer, print average latency
for summarizer in summarizers:
    avg_latency = df[f"summary_{summarizer}_latency"].mean()
    print(f"Average latency for {summarizer}: {avg_latency:.2f} seconds")
# Out:
# Average latency for random: 0.01 seconds
# Average latency for lsa: 0.04 seconds
# Average latency for text_rank: 0.03 seconds
# Average latency for spacy_textrank: 0.20 seconds
# Average latency for sentence_transformer_mpnet: 4.16 seconds
# Average latency for sentence_transformer_distiluse: 0.25 seconds
# Average latency for claude_haiku_3_5: 2.47 seconds
# Average latency for claude_sonnet_4: 3.55 seconds

# %%
df.columns
# Out:
# Index(['url', 'raw_markdown', 'language', 'domain', 'source', 'length',
#        'word_count', 'cleaned_markdown', 'summary_gt', 'summary_gt_extractive',
#        'summary_random', 'summary_lsa', 'summary_text_rank',
#        'summary_spacy_textrank', 'summary_sentence_transformer_mpnet',
#        'summary_sentence_transformer_distiluse', 'summary_claude_haiku_3_5',
#        'summary_claude_sonnet_4', 'summary_random_latency',
#        'summary_lsa_latency', 'summary_text_rank_latency',
#        'summary_spacy_textrank_latency',
#        'summary_sentence_transformer_mpnet_latency',
#        'summary_sentence_transformer_distiluse_latency',
#        'summary_claude_haiku_3_5_latency', 'summary_claude_sonnet_4_latency'],
#       dtype='object')
