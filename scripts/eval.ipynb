# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
from IPython.display import display
import evaluate

# %%
df = pd.read_csv("../dataset/results.csv")
df.columns
# Out:
# Index(['url', 'raw_markdown', 'language', 'domain', 'source', 'length',
#        'word_count', 'cleaned_markdown', 'summary_gt', 'summary_gt_extractive',
#        'summary_random', 'summary_lsa', 'summary_text_rank', 'summary_fast',
#        'summary_random_latency', 'summary_lsa_latency',
#        'summary_text_rank_latency', 'summary_fast_latency'],
#       dtype='object')

# %%
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

# %%
# 3. Preprocessing function
def preprocess(text: str) -> str:
    return " ".join(text.lower().split())

# %%
# Cell 3: Compute per-output metrics
summarizers = ['random', 'lsa', 'text_rank', 'fast']
records = []

for name in summarizers:
    print(f"Processing summarizer: {name}")
    pred_col = f"summary_{name}"
    
    # gt_col = "summary_gt"
    gt_col = "summary_gt_extractive"
    
    # Drop NaNs for evaluation
    eval_df = df.dropna(subset=[pred_col, gt_col])
    refs  = eval_df[gt_col].map(preprocess).tolist()
    preds = eval_df[pred_col].map(preprocess).tolist()
    
    # Compute BERTScore once per summarizer
    bert_scores = bertscore.compute(
        predictions=preds,
        references=refs,
        model_type="xlm-roberta-base",
        idf=False,
        batch_size=16,
    )
    
    # Now record metrics for each example
    for i, idx in enumerate(eval_df.index):
        # ROUGE on the single example
        rouge_score = rouge.compute(
            predictions=[preds[i]],
            references=[refs[i]],
            use_stemmer=True
        )
        
        records.append({
            "url":             df.loc[idx, "url"],
            "language":        df.loc[idx, "language"],
            "gt":              df.loc[idx, gt_col],
            "summary_pred":    df.loc[idx, pred_col],
            "length":          df.loc[idx, "length"],
            "summarizer":      name,
            "rouge1":          rouge_score["rouge1"],
            "rouge2":          rouge_score["rouge2"],
            "rougeL":          rouge_score["rougeL"],
            "rougeLsum":       rouge_score["rougeLsum"],
            "bert_precision":  bert_scores["precision"][i],
            "bert_recall":     bert_scores["recall"][i],
            "bert_f1":         bert_scores["f1"][i],
        })
# Out:
# Processing summarizer: random
# Processing summarizer: lsa
# Processing summarizer: text_rank
# Processing summarizer: fast
# Processing summarizer: summary_gt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43940\518335318.py in ?()
#       9     # gt_col = "summary_gt"
#      10     gt_col = "summary_gt_extractive"
#      11
#      12     # Drop NaNs for evaluation
# ---> 13     eval_df = df.dropna(subset=[pred_col, gt_col])
#      14     refs  = eval_df[gt_col].map(preprocess).tolist()
#      15     preds = eval_df[pred_col].map(preprocess).tolist()
#      16
#
# c:\repos\search-summaries\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6673             ax = self._get_axis(agg_axis)
#    6674             indices = ax.get_indexer_for(subset)
#    6675             check = indices == -1
#    6676             if check.any():
# -> 6677                 raise KeyError(np.array(subset)[check].tolist())
#    6678             agg_obj = self.take(indices, axis=agg_axis)
#    6679
#    6680         if thresh is not lib.no_default:
#
# KeyError: ['summary_summary_gt']

# %%
# Build the per-example metrics DataFrame
long_df = pd.DataFrame.from_records(records)

# %%
# Cell 4: Save and display
long_df.to_csv("../dataset/metrics_by_example.csv", index=False)
display("Per-example evaluation metrics", long_df)
print("✅ Saved per-example metrics to '../dataset/metrics_by_example.csv'")
# Out:
# 'Per-example evaluation metrics'
#                                                    url language  \
# 0    https://simple.wikipedia.org/wiki/Space_explor...  english
# 1     https://en.wikipedia.org/wiki/Portal:Mathematics  english
# 2            https://simple.wikipedia.org/wiki/History  english
# 3    https://en.wikipedia.org/wiki/Outline_of_machi...  english
# 4    https://en.wikipedia.org/wiki/Category:Astroph...  english
# ..                                                 ...      ...
# 772   https://www.bbc.com/arabic/tv-and-radio-67957982   arabic
# 773   https://www.bbc.com/arabic/articles/cj3rnmlkp5no   arabic
# 774           https://www.aljazeera.com/climate-crisis   arabic
# 775   https://www.bbc.com/arabic/articles/c0rgn20w5z2o   arabic
# 776   https://www.bbc.com/arabic/articles/c24pmrg927yo   arabic
#
#                                                     gt  \
# 0    Space exploration is a term which describes se...
# 1    Mathematics is the study of representing and r...
# 2    History is the study of past events. A person ...
# 3    The following outline is provided as an overvi...
# 4    Astrophysics is the branch of astronomy that d...
# ..                                                 ...
# 772  تربط منظمة الصحة العالمية الأخطاء الطبية الأكث...
# 773  وتُعدّ أمراض القلب والأوعية الدموية السبب الأو...
# 774  Six dead, thousands displaced as floods hit so...
# 775  ينذر التغير المناخي بتداعيات قد تغيّر شكل كوكب...
# 776  يرى برنامج الأمم المتحدة للبيئة (اليونيب) أن ت...
#
#                                           summary_pred  length summarizer  \
# 0    The most important reasons are for scientific ...    3603     random
# 1    Mathematics is used throughout the world as an...   71678     random
# 2    The rulers of Medieval Europe, Ancient Rome an...    3659     random
# 3    You can help by adding missing items with reli...  176774     random
# 4    Astrophysics is the branch of astronomy that d...    2469     random
# ..                                                 ...     ...        ...
# 772  Keywords : []\n- تربط منظمة الصحة العالمية الأ...    2458       fast
# 773  Keywords : []\n- صدر الصورة، Getty Images\nالق...   12087       fast
# 774  Keywords : []\n- Climate Crisis\nSix dead, tho...    1319       fast
# 775  Keywords : []\n- صدر الصورة، Getty Images\nينذ...   11747       fast
# 776  Keywords : []\n- صدر الصورة، Reuters\nقاتل صام...   10940       fast
#
#        rouge1    rouge2    rougeL  rougeLsum  bert_precision  bert_recall  \
# 0    0.521739  0.400000  0.456522   0.456522        0.897356     0.889501
# 1    0.206573  0.018957  0.122066   0.122066        0.790440     0.831968
# 2    0.283019  0.038462  0.188679   0.188679        0.824692     0.870355
# 3    0.228070  0.000000  0.087719   0.087719        0.831689     0.847245
# 4    0.618705  0.554745  0.604317   0.604317        0.954133     0.916818
# ..        ...       ...       ...        ...             ...          ...
# 772  0.666667  0.000000  0.666667   0.666667        0.962029     0.950823
# 773  0.285714  0.000000  0.285714   0.285714        0.861637     0.865236
# 774  0.666667  0.660714  0.666667   0.666667        0.886631     0.976901
# 775  0.222222  0.000000  0.222222   0.222222        0.887173     0.924986
# 776  0.000000  0.000000  0.000000   0.000000        0.830049     0.828512
#
#       bert_f1
# 0    0.893411
# 1    0.810673
# 2    0.846909
# 3    0.839395
# 4    0.935104
# ..        ...
# 772  0.956393
# 773  0.863432
# 774  0.929580
# 775  0.905685
# 776  0.829280
#
# [777 rows x 13 columns]
# ✅ Saved per-example metrics to '../dataset/metrics_by_example.csv'

# %%
# Define which metric columns to average
long_copy = long_df.copy()

# drop arabic and chinese
# long_copy = long_copy[~long_copy["language"].isin(["ar", "zh"])]

metrics = [
    "rouge1", "rouge2", "rougeL", "rougeLsum",
    "bert_precision", "bert_recall", "bert_f1"
]

# 1) Average result per summarizer
avg_by_summarizer = (
    long_copy
    .groupby("summarizer")[metrics]
    .mean()
    .reset_index()
)

# 2) Average result per summarizer per language
avg_by_summarizer_lang = (
    long_copy
    .groupby(["summarizer", "language"])[metrics]
    .mean()
    .sort_values(by=["language"])
    .reset_index()
)

# (Optional) Display or save
print("=== Avg per summarizer ===")
display(avg_by_summarizer)

print("\n=== Avg per summarizer per language ===")
display(avg_by_summarizer_lang)
# Out:
# === Avg per summarizer ===
#   summarizer    rouge1    rouge2    rougeL  rougeLsum  bert_precision  \
# 0       fast  0.351732  0.237601  0.277552   0.277552        0.854768
# 1        lsa  0.360343  0.231730  0.296557   0.296557        0.858334
# 2     random  0.279983  0.159767  0.228026   0.228026        0.854923
# 3  text_rank  0.328629  0.212571  0.273800   0.273800        0.847339
#
#    bert_recall   bert_f1
# 0     0.881270  0.867517
# 1     0.887643  0.872395
# 2     0.864298  0.859209
# 3     0.884469  0.865080
# === Avg per summarizer per language ===
#    summarizer language    rouge1    rouge2    rougeL  rougeLsum  \
# 0        fast   arabic  0.361312  0.201687  0.358372   0.358372
# 1      random   arabic  0.162884  0.060652  0.149879   0.149879
# 2   text_rank   arabic  0.217467  0.086294  0.197122   0.197122
# 3         lsa   arabic  0.220744  0.080777  0.202210   0.202210
# 4      random  chinese  0.130883  0.076831  0.124930   0.124930
# 5         lsa  chinese  0.182059  0.109524  0.174122   0.174122
# 6   text_rank  chinese  0.165059  0.066667  0.156401   0.156401
# 7        fast  chinese  0.128475  0.067233  0.128475   0.128475
# 8         lsa  english  0.444315  0.306121  0.366422   0.366422
# 9        fast  english  0.423898  0.295787  0.325237   0.325237
# 10     random  english  0.330345  0.199636  0.271148   0.271148
# 11  text_rank  english  0.415055  0.289055  0.346447   0.346447
# 12       fast   french  0.338719  0.199285  0.242687   0.242687
# 13     random   french  0.290898  0.149996  0.210878   0.210878
# 14  text_rank   french  0.262685  0.151409  0.200067   0.200067
# 15        lsa   french  0.337976  0.185151  0.253467   0.253467
# 16       fast   german  0.371442  0.282193  0.281091   0.281091
# 17        lsa   german  0.321120  0.210664  0.268703   0.268703
# 18  text_rank   german  0.307097  0.205723  0.257404   0.257404
# 19     random   german  0.270237  0.172432  0.233464   0.233464
# 20        lsa  spanish  0.342652  0.207817  0.265034   0.265034
# 21       fast  spanish  0.322620  0.218304  0.249824   0.249824
# 22     random  spanish  0.288374  0.140300  0.213595   0.213595
# 23  text_rank  spanish  0.292848  0.185870  0.231857   0.231857
#
#     bert_precision  bert_recall   bert_f1
# 0         0.896181     0.913422  0.904501
# 1         0.865739     0.861449  0.863246
# 2         0.847097     0.882530  0.863873
# 3         0.849971     0.869089  0.858901
# 4         0.864816     0.871434  0.867957
# 5         0.852180     0.883592  0.867376
# 6         0.851089     0.883354  0.866825
# 7         0.829345     0.864974  0.846600
# 8         0.866107     0.896526  0.880721
# 9         0.863065     0.885195  0.873688
# 10        0.858803     0.863607  0.860864
# 11        0.856878     0.889197  0.872256
# 12        0.841204     0.865068  0.852633
# 13        0.845603     0.849784  0.847554
# 14        0.813658     0.864148  0.837875
# 15        0.855352     0.868556  0.861686
# 16        0.857554     0.874037  0.865603
# 17        0.848212     0.877337  0.862309
# 18        0.842345     0.870798  0.856044
# 19        0.846088     0.854315  0.849797
# 20        0.853088     0.891067  0.871174
# 21        0.840543     0.884566  0.861616
# 22        0.844338     0.877986  0.860265
# 23        0.839993     0.893903  0.865658
